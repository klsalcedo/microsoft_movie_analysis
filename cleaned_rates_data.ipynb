# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
rtRev_df = pd.read_csv('rt.reviews.tsv', delimiter='\t', encoding='latin1')
rtRev_df
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
#created new df without all the NaN values in rating column, dropped 13517 rows
cleaned_df = (rtRev_df[rtRev_df['rating'].notna()]).copy()
cleaned_df.head()
# Out:
#     id                                             review rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 6    3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7    3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 11   3  While not one of Cronenberg's stronger films, ...     B-   fresh
# 12   3  Robert Pattinson works mighty hard to make Cos...    2/4  rotten
#
#             critic  top_critic           publisher               date
# 0       PJ Nabarro           0     Patrick Nabarro  November 10, 2018
# 6   Eric D. Snider           0     EricDSnider.com      July 17, 2013
# 7     Matt Kelemen           0  Las Vegas CityLife     April 21, 2013
# 11    Emanuel Levy           0     EmanuelLevy.Com   February 3, 2013
# 12  Christian Toto           0       Big Hollywood   January 15, 2013

# %%
cleaned_df.shape
# Out:
# (40915, 8)

# %%
#created a new df where all the rows have a letter as the value in the rating column
df_letters = rtRev_df[rtRev_df['rating'].isin(['A+','A','A-','B+','B','B-','C+','C','C-','D+','D','D-','F+','F','F-','N','T','R'])].copy()
df_letters.head()
# Out:
#     id                                             review rating   fresh  \
# 6    3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 11   3  While not one of Cronenberg's stronger films, ...     B-   fresh
# 13   3  The anger over the injustice of the financial ...      B   fresh
# 17   3      Its major problem is that it's not cinematic.      B   fresh
# 34   3  I don't know if DeLillo's fetishized doubletal...      C  rotten
#
#              critic  top_critic                  publisher                date
# 6    Eric D. Snider           0            EricDSnider.com       July 17, 2013
# 11     Emanuel Levy           0            EmanuelLevy.Com    February 3, 2013
# 13     Robert Roten           0        Laramie Movie Scope     January 7, 2013
# 17  Dennis Schwartz           0  Ozus' World Movie Reviews  September 25, 2012
# 34  Vincent Mancini           0                  FilmDrunk     August 30, 2012

# %%
df_letters.shape
# Out:
# (6468, 8)

# %%
#used the letters_df to rid the letters from the no-Nan cleaned_df
cleaned_df.drop(cleaned_df[cleaned_df['rating'].isin(df_letters['rating'])].index, inplace=True)
cleaned_df.shape
# Out:
# (34447, 8)

# %%
cleaned_df['rating'].unique()
# Out:
# array(['3/5', '2/5', '2/4', '3/4', '4/5', '4/4', '6/10', '1/4', '8',
#        '2.5/4', '4/10', '2.0/5', '3/10', '7/10', '5/5', '3.5/4', '1.5/4',
#        '3.5/5', '8/10', '9/10', '2.5/5', '7.5/10', '5.5/10', '1.5/5',
#        '1/5', '5/10', '0/5', '6', '0.5/4', '3.1/5', '3/6', '4.5/5', '0/4',
#        '2/10', '7', '1/10', '3', '4.0/4', '9.5/10', '2.5', '2.1/2',
#        '6.5/10', '3.7/5', '8.4/10', '9', '1', '7.2/10', '2.2/5', '0.5/10',
#        '5', '0', '2', '4.5', '7.7', '5.0/5', '8.5/10', '3.0/5', '0.5/5',
#        '1.5/10', '3.0/4', '2.3/10', '4.5/10', '4/6', '3.5', '8.6/10',
#        '6/8', '2.0/4', '2.7', '4.2/10', '5.8', '4', '7.1/10', '5/4',
#        '3.5/10', '5.8/10', '4.0/5', '0/10', '5.0/10', '5.9/10', '2.4/5',
#        '1.9/5', '4.9', '7.4/10', '1.5', '2.3/4', '8.8/10', '4.0/10',
#        '2.2', '3.8/10', '6.8/10', '7.3', '7.0/10', '3.2', '4.2', '8.4',
#        '5.5/5', '6.3/10', '7.6/10', '8.1/10', '3.6/5', '2/6', '7.7/10',
#        '1.8', '8.9/10', '8.9', '8.2/10', '8.3/10', '2.6/6', '4.1/10',
#        '2.5/10', '6.0/10', '1.0/4', '7.9/10', '8.7/10', '4.3/10',
#        '9.6/10', '9.0/10', '4.0', '1.7', '7.9', '6.7', '8.0/10', '9.2/10',
#        '5.2', '5.9', '3.7', '4.7', '6.2/10', '1/6', '8.2', '2.6/5', '3.4',
#        '9.7', '3.3/5', '3.8/5', '1/2', '7.4', '4.8', '1.6/5', '2/2',
#        '1-5', '1.0', '4.3/5', '5/6', '9.2', '2.7/5', '4.9/10', '3.0',
#        '3.1', '7.8/10', '2.3/5', '3.0/10', '3/2', '7.8', '4.2/5', '9.0',
#        '7.3/10', '4.4/5', '6.9/10', '0/6', '6.2', '3.3', '9.8', '8.5',
#        '1.0/5', '4.1', '7.1', '3 1/2'], dtype=object)

# %%
#get list of string data values from rating column
values = []
for rating_value in cleaned_df['rating']:
    values.append(rating_value)

#partition and convert string values to float, interpreted the 1-5 as 1.5
to_num = []
for item in values:
    if item == '3 1/2':
        to_num.append(3.5)
    elif '/' in item:
        x = item.partition('/')
        to_num.append(float(x[0]))
    elif item == '1-5':
        to_num.append(1.5)
    else:
        to_num.append(float(item))

#rating should be 0-5 so half any ratings that are above 5, overall 3044 ratings over 5
five_rating = []
for element in to_num:
    if element > 5:
        y = element/2
        five_rating.append(y)
    else:
        five_rating.append(element)

#add new column 'cleaned_rating' w cleaned ratings   
cleaned_df['cleaned_rating'] = five_rating
cleaned_df.head()
# Out:
#     id                                             review rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 7    3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 12   3  Robert Pattinson works mighty hard to make Cos...    2/4  rotten
# 14   3  For those who like their Cronenberg thick and ...    3/4   fresh
# 15   3  For better or worse - often both - Cosmopolis ...    3/5   fresh
#
#             critic  top_critic           publisher                date  \
# 0       PJ Nabarro           0     Patrick Nabarro   November 10, 2018
# 7     Matt Kelemen           0  Las Vegas CityLife      April 21, 2013
# 12  Christian Toto           0       Big Hollywood    January 15, 2013
# 14     Marty Mapes           0         Movie Habit    October 20, 2012
# 15       Adam Ross           0      The Aristocrat  September 27, 2012
#
#     cleaned_rating
# 0              3.0
# 7              2.0
# 12             2.0
# 14             3.0
# 15             3.0

# %%
#get the median for new_rating grouped by the movie id, also shows there are 1077 unique values in id column
group = cleaned_df.groupby(['id']).median()
group.drop(['top_critic'], axis=1, inplace=True)
group
# Out:
#       cleaned_rating
# id
# 3               3.00
# 5               3.00
# 6               3.00
# 8               3.00
# 10              3.00
# ...              ...
# 1996            3.00
# 1997            2.00
# 1998            3.00
# 1999            3.00
# 2000            2.25
#
# [1077 rows x 1 columns]

# %%
#merge df with letters rating with the df with the median for new_rating, dropped 47 rows as those 47 had an
#id whose value in the rating (original) was only ever a letter i.e. no way to calculate a median
combined = df_letters.merge(group, how='inner', on='id')
combined
# Out:
#         id                                             review rating   fresh  \
# 0        3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 1        3  While not one of Cronenberg's stronger films, ...     B-   fresh
# 2        3  The anger over the injustice of the financial ...      B   fresh
# 3        3      Its major problem is that it's not cinematic.      B   fresh
# 4        3  I don't know if DeLillo's fetishized doubletal...      C  rotten
# ...    ...                                                ...    ...     ...
# 6416  2000  If you sometimes like to go to the movies to h...      A   fresh
# 6417  2000  May lack the pungent bite of its title, but it...     C+   fresh
# 6418  2000  Wasabi does its job colorfully and entertainin...     C+   fresh
# 6419  2000  Slight, but colorful and forward-moving... Was...     C+   fresh
# 6420  2000          Despite the title, Wasabi isn't so spicy.      C  rotten
#
#                critic  top_critic                       publisher  \
# 0      Eric D. Snider           0                 EricDSnider.com
# 1        Emanuel Levy           0                 EmanuelLevy.Com
# 2        Robert Roten           0             Laramie Movie Scope
# 3     Dennis Schwartz           0       Ozus' World Movie Reviews
# 4     Vincent Mancini           0                       FilmDrunk
# ...               ...         ...                             ...
# 6416    Edward Havens           0                    FilmJerk.com
# 6417    Marshall Fine           0  Journal News (Westchester, NY)
# 6418     Sean Axmaker           0      Seattle Post-Intelligencer
# 6419      Brent Simon           0             Entertainment Today
# 6420              NaN           0                       E! Online
#
#                     date  cleaned_rating
# 0          July 17, 2013            3.00
# 1       February 3, 2013            3.00
# 2        January 7, 2013            3.00
# 3     September 25, 2012            3.00
# 4        August 30, 2012            3.00
# ...                  ...             ...
# 6416    October 12, 2002            2.25
# 6417     October 5, 2002            2.25
# 6418     October 3, 2002            2.25
# 6419  September 30, 2002            2.25
# 6420  September 27, 2002            2.25
#
# [6421 rows x 9 columns]

# %%
#use concat to join cleaned_df (which has the cleaned_rating column) with the combined df (which has 
#median value for letter ratings as cleaned_rating) since combined has rows earlier dropped from cleaned_df
all_data = pd.concat([cleaned_df, combined])
all_data.head()
# Out:
#     id                                             review rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 7    3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 12   3  Robert Pattinson works mighty hard to make Cos...    2/4  rotten
# 14   3  For those who like their Cronenberg thick and ...    3/4   fresh
# 15   3  For better or worse - often both - Cosmopolis ...    3/5   fresh
#
#             critic  top_critic           publisher                date  \
# 0       PJ Nabarro           0     Patrick Nabarro   November 10, 2018
# 7     Matt Kelemen           0  Las Vegas CityLife      April 21, 2013
# 12  Christian Toto           0       Big Hollywood    January 15, 2013
# 14     Marty Mapes           0         Movie Habit    October 20, 2012
# 15       Adam Ross           0      The Aristocrat  September 27, 2012
#
#     cleaned_rating
# 0              3.0
# 7              2.0
# 12             2.0
# 14             3.0
# 15             3.0

# %%
#df with movie info, use to obtain genres
rt_df = pd.read_csv('rt.movie_info.tsv', delimiter='\t') 
rt_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
rt_df.shape
# Out:
# (1560, 12)

# %%
#merged the all_data df w the rotten tomatoes movie info df on the id column to get genres
w_genres_df = all_data.merge(rt_df, how='left', on='id')
w_genres_df.head()
# Out:
#    id                                             review rating_x   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...      3/5   fresh
# 1   3  Cronenberg is not a director to be daunted by ...      2/5  rotten
# 2   3  Robert Pattinson works mighty hard to make Cos...      2/4  rotten
# 3   3  For those who like their Cronenberg thick and ...      3/4   fresh
# 4   3  For better or worse - often both - Cosmopolis ...      3/5   fresh
#
#            critic  top_critic           publisher                date  \
# 0      PJ Nabarro           0     Patrick Nabarro   November 10, 2018
# 1    Matt Kelemen           0  Las Vegas CityLife      April 21, 2013
# 2  Christian Toto           0       Big Hollywood    January 15, 2013
# 3     Marty Mapes           0         Movie Habit    October 20, 2012
# 4       Adam Ross           0      The Aristocrat  September 27, 2012
#
#    cleaned_rating                                           synopsis rating_y  \
# 0             3.0  New York City, not-too-distant-future: Eric Pa...        R
# 1             2.0  New York City, not-too-distant-future: Eric Pa...        R
# 2             2.0  New York City, not-too-distant-future: Eric Pa...        R
# 3             3.0  New York City, not-too-distant-future: Eric Pa...        R
# 4             3.0  New York City, not-too-distant-future: Eric Pa...        R
#
#                                genre          director  \
# 0  Drama|Science Fiction and Fantasy  David Cronenberg
# 1  Drama|Science Fiction and Fantasy  David Cronenberg
# 2  Drama|Science Fiction and Fantasy  David Cronenberg
# 3  Drama|Science Fiction and Fantasy  David Cronenberg
# 4  Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date     dvd_date currency  \
# 0  David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 2  David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 3  David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
# 4  David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
#
#   box_office      runtime             studio
# 0    600,000  108 minutes  Entertainment One
# 1    600,000  108 minutes  Entertainment One
# 2    600,000  108 minutes  Entertainment One
# 3    600,000  108 minutes  Entertainment One
# 4    600,000  108 minutes  Entertainment One

# %%
#dropped columns that seemed superfluous, shape = (40868,14)
w_genres_df.drop(labels=['critic','publisher','top_critic','rating_y','dvd_date','studio'],axis=1, inplace=True)
w_genres_df.head()
# Out:
#    id                                             review rating_x   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...      3/5   fresh
# 1   3  Cronenberg is not a director to be daunted by ...      2/5  rotten
# 2   3  Robert Pattinson works mighty hard to make Cos...      2/4  rotten
# 3   3  For those who like their Cronenberg thick and ...      3/4   fresh
# 4   3  For better or worse - often both - Cosmopolis ...      3/5   fresh
#
#                  date  cleaned_rating  \
# 0   November 10, 2018             3.0
# 1      April 21, 2013             2.0
# 2    January 15, 2013             2.0
# 3    October 20, 2012             3.0
# 4  September 27, 2012             3.0
#
#                                             synopsis  \
# 0  New York City, not-too-distant-future: Eric Pa...
# 1  New York City, not-too-distant-future: Eric Pa...
# 2  New York City, not-too-distant-future: Eric Pa...
# 3  New York City, not-too-distant-future: Eric Pa...
# 4  New York City, not-too-distant-future: Eric Pa...
#
#                                genre          director  \
# 0  Drama|Science Fiction and Fantasy  David Cronenberg
# 1  Drama|Science Fiction and Fantasy  David Cronenberg
# 2  Drama|Science Fiction and Fantasy  David Cronenberg
# 3  Drama|Science Fiction and Fantasy  David Cronenberg
# 4  Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date currency box_office      runtime
# 0  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 2  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 3  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 4  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes

# %%
w_genres_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40868 entries, 0 to 40867
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              40868 non-null  int64
#  1   review          35334 non-null  object
#  2   rating_x        40868 non-null  object
#  3   fresh           40868 non-null  object
#  4   date            40868 non-null  object
#  5   cleaned_rating  40868 non-null  float64
#  6   synopsis        40763 non-null  object
#  7   genre           40792 non-null  object
#  8   director        36656 non-null  object
#  9   writer          33898 non-null  object
#  10  theater_date    39985 non-null  object
#  11  currency        25538 non-null  object
#  12  box_office      25538 non-null  object
#  13  runtime         40250 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 4.7+ MB

# %%
#made a copy of w_genres_df and dropped the rows with NaN values in genre column
filled_genres = w_genres_df.dropna(subset=['genre']).copy()
filled_genres.head()
# Out:
#    id                                             review rating_x   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...      3/5   fresh
# 1   3  Cronenberg is not a director to be daunted by ...      2/5  rotten
# 2   3  Robert Pattinson works mighty hard to make Cos...      2/4  rotten
# 3   3  For those who like their Cronenberg thick and ...      3/4   fresh
# 4   3  For better or worse - often both - Cosmopolis ...      3/5   fresh
#
#                  date  cleaned_rating  \
# 0   November 10, 2018             3.0
# 1      April 21, 2013             2.0
# 2    January 15, 2013             2.0
# 3    October 20, 2012             3.0
# 4  September 27, 2012             3.0
#
#                                             synopsis  \
# 0  New York City, not-too-distant-future: Eric Pa...
# 1  New York City, not-too-distant-future: Eric Pa...
# 2  New York City, not-too-distant-future: Eric Pa...
# 3  New York City, not-too-distant-future: Eric Pa...
# 4  New York City, not-too-distant-future: Eric Pa...
#
#                                genre          director  \
# 0  Drama|Science Fiction and Fantasy  David Cronenberg
# 1  Drama|Science Fiction and Fantasy  David Cronenberg
# 2  Drama|Science Fiction and Fantasy  David Cronenberg
# 3  Drama|Science Fiction and Fantasy  David Cronenberg
# 4  Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date currency box_office      runtime
# 0  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 2  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 3  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes
# 4  David Cronenberg|Don DeLillo  Aug 17, 2012        $    600,000  108 minutes

# %%
#separate the grouped genres in the genre column into individual genres
separated = []
word = ''
for genre in filled_genres['genre']:
    counter = genre.count('|') + 1
    word = genre
    while counter > 0:
        part = word.partition('|')
        separated.append(part[0])
        word = part[2]
        counter -= 1

# %%
#get a list of the unique genres 
distinct = set(separated)
distinct
# Out:
# {'Action and Adventure',
#  'Animation',
#  'Anime and Manga',
#  'Art House and International',
#  'Classics',
#  'Comedy',
#  'Cult Movies',
#  'Documentary',
#  'Drama',
#  'Faith and Spirituality',
#  'Gay and Lesbian',
#  'Horror',
#  'Kids and Family',
#  'Musical and Performing Arts',
#  'Mystery and Suspense',
#  'Romance',
#  'Science Fiction and Fantasy',
#  'Special Interest',
#  'Sports and Fitness',
#  'Television',
#  'Western'}

# %%
#get boolean values for each movie for each distinct genre, will be in a list of lists
genre_by_row = []
for item in distinct:
    distinct_values = []
    for genre in filled_genres['genre']:
        if item in genre:
            distinct_values.append(True)
        else:
            distinct_values.append(False)
    genre_by_row.append(distinct_values)

# %%
len(genre_by_row)
# Out:
# 21

# %%
len(distinct)
# Out:
# 21

# %%
#assign boolean values to distinct genre columns to add to filled_genre df
index = 0
for item in distinct:
    filled_genres[item] = genre_by_row[index]
    index += 1
    
filled_genres.head()
# Out:
#    id                                             review rating_x   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...      3/5   fresh
# 1   3  Cronenberg is not a director to be daunted by ...      2/5  rotten
# 2   3  Robert Pattinson works mighty hard to make Cos...      2/4  rotten
# 3   3  For those who like their Cronenberg thick and ...      3/4   fresh
# 4   3  For better or worse - often both - Cosmopolis ...      3/5   fresh
#
#                  date  cleaned_rating  \
# 0   November 10, 2018             3.0
# 1      April 21, 2013             2.0
# 2    January 15, 2013             2.0
# 3    October 20, 2012             3.0
# 4  September 27, 2012             3.0
#
#                                             synopsis  \
# 0  New York City, not-too-distant-future: Eric Pa...
# 1  New York City, not-too-distant-future: Eric Pa...
# 2  New York City, not-too-distant-future: Eric Pa...
# 3  New York City, not-too-distant-future: Eric Pa...
# 4  New York City, not-too-distant-future: Eric Pa...
#
#                                genre          director  \
# 0  Drama|Science Fiction and Fantasy  David Cronenberg
# 1  Drama|Science Fiction and Fantasy  David Cronenberg
# 2  Drama|Science Fiction and Fantasy  David Cronenberg
# 3  Drama|Science Fiction and Fantasy  David Cronenberg
# 4  Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  ... Comedy Art House and International  \
# 0  David Cronenberg|Don DeLillo  ...  False                       False
# 1  David Cronenberg|Don DeLillo  ...  False                       False
# 2  David Cronenberg|Don DeLillo  ...  False                       False
# 3  David Cronenberg|Don DeLillo  ...  False                       False
# 4  David Cronenberg|Don DeLillo  ...  False                       False
#
#   Kids and Family Horror  Television  Science Fiction and Fantasy  Romance  \
# 0           False  False       False                         True    False
# 1           False  False       False                         True    False
# 2           False  False       False                         True    False
# 3           False  False       False                         True    False
# 4           False  False       False                         True    False
#
#    Anime and Manga  Faith and Spirituality  Classics
# 0            False                   False     False
# 1            False                   False     False
# 2            False                   False     False
# 3            False                   False     False
# 4            False                   False     False
#
# [5 rows x 35 columns]

# %%
def rate_round(rate):
    return round(rate)

# %%
#create df with genres, rating, and theater date, drop superfluous columns, change cleaned_rating to Rating, round
#ratings, drop rows with NaN in theater_date column
genres_w_date = filled_genres.copy()
genres_w_date.drop(labels = ['id', 'review', 'rating_x', 'fresh', 'genre', 'runtime', 'Television', 'director',
                  'synopsis', 'writer', 'date'], axis=1, inplace=True)
genres_w_date.rename(columns = {'cleaned_rating':'Rating'}, inplace=True)
genres_w_date.Rating = genres_w_date.Rating.apply(rate_round)
genres_w_date.dropna(subset = ['theater_date'], inplace=True)

# %%
def get_year(date):
    date = date.replace('\n','')
    date = date.strip()
    year = int(date[-4:])
    return year

# %%
genres_w_date.theater_date.unique()
# Out:
# array(['Aug 17, 2012', 'Sep 13, 1996', 'Dec 9, 1994', 'Mar 3, 2000',
#        'Jan 11, 2002', 'Apr 27, 2006', 'Jun 30, 2010', 'Jun 9, 1995',
#        'Aug 23, 2002', 'Dec 22, 1968', 'Jan 31, 1997', 'Dec 20, 2013',
#        'Nov 6, 1987', 'Dec 25, 2013', 'May 14, 2004', 'Jun 15, 1966',
#        'Nov 1, 1996', 'Dec 31, 2000', 'Jul 30, 1999', 'Dec 23, 1970',
#        'Sep 19, 2003', 'May 16, 2003', 'Mar 11, 2003', 'Aug 13, 1997',
#        'Oct 26, 1967', 'Apr 21, 1995', 'Nov 15, 2013', 'Oct 6, 1995',
#        'Nov 21, 2012', 'Jan 27, 1984', 'Jan 1, 1987', 'Feb 10, 2006',
#        'Mar 26, 1997', 'Aug 21, 1998', 'Nov 21, 2007', 'Jan 17, 2014',
#        'Sep 21, 1940', 'Jun 12, 1981', 'May 14, 1986', 'Apr 6, 1965',
#        'Jul 1, 2011', 'May 19, 1995', 'Dec 3, 1987', 'Jan 19, 2001',
#        'Aug 20, 2010', 'Jul 24, 1998', 'Jan 1, 1966', 'Nov 3, 1939',
#        'Nov 18, 2016', 'Dec 20, 2002', 'Apr 16, 2010', 'Dec 25, 1946',
#        'Nov 24, 1999', 'Sep 10, 1989', 'Dec 25, 1999', 'Aug 7, 1998',
#        'Jul 30, 1993', 'Jul 12, 2002', 'Aug 17, 1984', 'Nov 2, 1990',
#        'Jan 9, 2008', 'Apr 4, 2003', 'Jan 1, 1973', 'Jan 1, 2001',
#        'Oct 1, 2010', 'Mar 1, 1996', 'Sep 13, 1978', 'Oct 21, 1937',
#        'Apr 18, 1997', 'Dec 21, 1984', 'Jan 28, 1986', 'Oct 15, 1951',
#        'Mar 10, 1995', 'Mar 19, 2010', 'Oct 1, 1958', 'Dec 11, 2009',
#        'Sep 3, 2003', 'Dec 8, 2000', 'Jul 24, 1992', 'Feb 2, 2001',
#        'Jan 1, 1945', 'Jun 1, 1992', 'Sep 28, 1994', 'Jan 16, 2009',
#        'Sep 4, 1942', 'Oct 18, 1991', 'Dec 8, 1988', 'Jun 8, 2012',
#        'Jul 12, 2013', 'Jul 29, 1983', 'Mar 27, 1963', 'Apr 30, 1999',
#        'Apr 22, 2005', 'Jun 1, 1980', 'Jan 13, 2017', 'May 3, 1944',
#        'Jan 1, 1994', 'Dec 14, 1985', 'Mar 4, 1922', 'Sep 2, 2016',
#        'Sep 23, 2000', 'Apr 3, 2009', 'Dec 31, 1950', 'Feb 9, 1933',
#        'Oct 18, 2002', 'Jun 21, 1966', 'Jun 1, 1957', 'Jan 1, 1962',
#        'Oct 15, 1965', 'Oct 16, 1998', 'Aug 14, 2009', 'Nov 18, 1994',
#        'Jan 19, 1990', 'May 5, 2000', 'Mar 22, 1932', 'Nov 10, 1999',
#        'Sep 10, 1999', 'Jun 23, 2006', 'Nov 20, 2015', 'Apr 6, 1990',
#        'May 9, 1973', 'Aug 19, 1988', 'Aug 30, 1991', 'Sep 2, 1950',
#        'Apr 11, 2003', 'Feb 8, 1991', 'Sep 21, 2007', 'May 5, 1983',
#        'Nov 25, 2005', 'Jan 29, 2016', 'Dec 14, 1979', 'Nov 16, 1994',
#        'May 30, 2014', 'Jul 1, 2016', 'Mar 1, 1980', 'Mar 2, 2012',
#        'Apr 1, 1994', 'Dec 31, 1960', 'Jul 28, 2006', 'Sep 5, 1991',
#        'Mar 18, 1964', 'Oct 27, 1989', 'Jun 23, 1970', 'Sep 1, 2006',
#        'Aug 13, 2010', 'Mar 12, 2004', 'Mar 9, 2012', 'Jun 25, 1982',
#        'Nov 5, 1956', 'Jul 29, 1965', 'Jan 1, 1993', 'Jun 5, 1987',
#        'Feb 7, 2013', 'Oct 16, 2015', 'Jan 1, 1967', 'Nov 4, 1964',
#        'Jul 10, 2009', 'Dec 23, 1968', 'Dec 21, 2011', 'Oct 22, 2010',
#        'Mar 14, 2014', 'Aug 11, 2000', 'Jan 1, 1956', 'Jun 1, 1995',
#        'May 14, 2010', 'Mar 4, 1943', 'Apr 18, 2014', 'Mar 10, 2006',
#        'Nov 20, 2009', 'May 28, 1982', 'Jan 12, 1966', 'Nov 19, 1993',
#        'Sep 11, 1998', 'Nov 3, 1953', 'Apr 1, 1989', 'Nov 17, 2000',
#        'Jul 20, 2007', 'Feb 18, 2000', 'Aug 28, 2009', 'Mar 15, 2002',
#        'Jan 19, 1942', 'Jun 27, 1973', 'Apr 10, 1968', 'Jan 1, 1947',
#        'May 3, 1995', 'Jul 7, 1960', 'Mar 16, 2018', 'Oct 22, 1986',
#        'Sep 20, 2002', 'Feb 7, 1997', 'Dec 15, 1993', 'Jul 1, 1987',
#        'Jan 11, 2013', 'Dec 5, 2008', 'Jun 6, 1980', 'Feb 12, 1982',
#        'Jan 16, 1998', 'Feb 20, 2008', 'Aug 3, 2018', 'Feb 1, 2013',
#        'Nov 7, 1997', 'Dec 13, 2002', 'Nov 16, 1990', 'Jun 29, 2001',
#        'Jun 14, 2002', 'Jan 12, 1977', 'Sep 11, 1968', 'Jun 21, 1985',
#        'Jul 8, 2005', 'Apr 19, 1991', 'Jun 13, 1971', 'Dec 10, 1964',
#        'Nov 4, 1994', 'Jul 31, 2009', 'Apr 21, 2006', 'Mar 27, 1981',
#        'Jun 10, 2011', 'Sep 10, 1991', 'Nov 13, 1998', 'Apr 30, 2004',
#        'Jan 1, 1971', 'Sep 14, 2001', 'Jan 17, 1986', 'Apr 16, 1998',
#        'Apr 9, 1986', 'Oct 8, 2003', 'Dec 31, 1976', 'Jul 14, 2000',
#        'Mar 11, 2011', 'Aug 19, 2016', 'Apr 6, 2012', 'Dec 9, 1987',
#        'Nov 2, 2007', 'Apr 11, 1990', 'Dec 21, 2005', 'Nov 16, 1984',
#        'Jan 1, 1988', 'Dec 25, 1985', 'Jul 23, 2002', 'Jun 21, 2009',
#        'Jun 7, 1970', 'Jun 11, 2004', 'May 31, 2013', 'Feb 28, 1992',
#        'Jan 19, 1996', 'Feb 6, 2015', 'Apr 1, 1982', 'Dec 26, 1957',
#        'Nov 3, 1971', 'Nov 28, 2007', 'Sep 8, 1995', 'Dec 21, 1979',
#        'Aug 4, 2000', 'Jun 26, 1998', 'Oct 5, 2001', 'Sep 29, 1945',
#        'Dec 12, 1968', 'Dec 22, 1964', 'Jan 1, 1997', 'Jun 18, 2010',
#        'Oct 20, 1995', 'Aug 20, 1993', 'Aug 1, 2000', 'Feb 4, 2005',
#        'Nov 21, 2008', 'Oct 9, 1993', 'Aug 17, 1979', 'Dec 22, 2017',
#        'Nov 1, 1974', 'Jan 17, 2003', 'Sep 23, 2005', 'Jan 30, 1987',
#        'Apr 6, 2018', 'Sep 29, 1944', 'Oct 23, 1998', 'Jul 25, 2014',
#        'Nov 9, 1970', 'Jul 30, 1976', 'Feb 29, 2008', 'Jun 8, 1984',
#        'Dec 22, 1995', 'Aug 17, 2007', 'Dec 23, 1988', 'Jul 24, 1987',
#        'Jul 23, 1993', 'Mar 31, 1995', 'May 23, 2014', 'Feb 2, 1967',
#        'Dec 10, 2010', 'Nov 22, 1995', 'Jan 1, 1940', 'Apr 26, 2002',
#        'Feb 27, 2008', 'Mar 12, 2010', 'Sep 27, 1996', 'Oct 1, 1999',
#        'Jan 1, 1949', 'Apr 4, 1959', 'Dec 29, 1971', 'Feb 28, 1986',
#        'Oct 3, 1993', 'Apr 3, 1998', 'Mar 21, 1995', 'Apr 19, 2002',
#        'May 22, 1992', 'May 20, 2016', 'Oct 4, 1996', 'Jan 9, 2009',
#        'Oct 24, 2003', 'Jul 27, 2012', 'Dec 19, 1990', 'Aug 7, 1987',
#        'Sep 17, 2010', 'Jan 24, 2014', 'Mar 28, 1980', 'Jun 9, 1978',
#        'Jan 9, 2015', 'Sep 20, 1962', 'Mar 24, 1995', 'Nov 25, 1987',
#        'Jun 7, 1940', 'Dec 5, 1986', 'Feb 16, 1988', 'Jul 4, 2001',
#        'Mar 4, 1994', 'Dec 21, 1959', 'Aug 4, 2017', 'Jun 26, 2015',
#        'Sep 28, 2001', 'Jan 1, 1983', 'Oct 11, 1996', 'Dec 10, 1965',
#        'Nov 6, 1998', 'Jun 1, 1985', 'Oct 8, 1997', 'Jan 12, 1990',
#        'Jul 18, 2001', 'Sep 12, 1997', 'Sep 16, 1983', 'Jan 1, 1999',
#        'Oct 13, 2006', 'Nov 26, 2003', 'Jul 13, 2016', 'Sep 3, 1993',
#        'Jun 2, 2001', 'Jan 1, 1937', 'Dec 31, 1985', 'May 18, 2018',
#        'Jan 25, 2008', 'Feb 11, 1980', 'Sep 26, 1980', 'Aug 3, 1979',
#        'Oct 19, 2007', 'Dec 1, 2017', 'Aug 10, 1960', 'Mar 11, 2016',
#        'Nov 6, 1992', 'Jan 1, 1990', 'Feb 2, 1990', 'Oct 23, 2015',
#        'Jul 25, 1997', 'Sep 22, 1995', 'Jan 1, 1958', 'Jul 27, 2001',
#        'Dec 15, 2008', 'May 15, 1957', 'Mar 19, 1993', 'Jun 22, 2003',
#        'Sep 28, 1955', 'Feb 19, 1960', 'Aug 4, 1993', 'Jul 31, 2008',
#        'Apr 26, 1996', 'Dec 16, 1970', 'Nov 19, 1932', 'Jun 29, 2005',
#        'Apr 17, 2009', 'Feb 17, 1938', 'Feb 9, 2007', 'Jun 1, 1987',
#        'Jan 22, 2008', 'Jun 19, 1981', 'Jan 1, 1996', 'Sep 24, 2003',
#        'Nov 11, 1988', 'Oct 10, 1995', 'Nov 5, 1993', 'Jul 13, 2006',
#        'Dec 4, 2009', 'Dec 19, 1963', 'Nov 18, 1983', 'Jul 30, 2010',
#        'May 21, 1999', 'Apr 1, 2007', 'Dec 22, 2004', 'Dec 25, 1974',
#        'Nov 5, 2004', 'Nov 22, 2013', 'May 11, 1984', 'Jun 18, 1999',
#        'Jun 8, 2001', 'Jan 1, 1992', 'Jun 1, 1988', 'May 11, 1944',
#        'Sep 9, 1986', 'Sep 9, 1992', 'Mar 18, 1988', 'Jan 31, 1992',
#        'Sep 25, 2009', 'Apr 1, 2000', 'Feb 21, 1952', 'Jul 19, 1996',
#        'Feb 11, 2011', 'Apr 23, 1982', 'Jun 1, 1993', 'May 27, 1970',
#        'Aug 26, 1947', 'May 3, 1996', 'Dec 12, 1997', 'Oct 8, 1969',
#        'Apr 11, 1997', 'May 1, 1941', 'Jun 27, 1957', 'Apr 9, 2003',
#        'May 24, 2002', 'Oct 3, 2003', 'Feb 22, 1985', 'Oct 1, 2004',
#        'May 4, 2001', 'Jun 22, 1966', 'Oct 21, 2005', 'Aug 28, 1992',
#        'Jan 9, 2004', 'May 11, 1973', 'Mar 11, 1971', 'Dec 18, 1969',
#        'Dec 21, 2001', 'Apr 11, 1980', 'Jan 12, 1983', 'Aug 12, 1988',
#        'Nov 18, 1988', 'Oct 9, 1999', 'Dec 16, 1985', 'May 22, 1987',
#        'Jun 13, 1973', 'Dec 17, 2010', 'Aug 12, 2011', 'Jan 27, 2012',
#        'Dec 25, 2008', 'Apr 14, 1989', 'Feb 9, 1977', 'Jul 8, 1948',
#        'Mar 26, 1975', 'Aug 29, 1963', 'Dec 27, 1958', 'Oct 28, 1983',
#        'Dec 2, 1993', 'Dec 7, 2012', 'Feb 7, 2003', 'May 7, 2010',
#        'Oct 3, 1955', 'Sep 21, 2018', 'Aug 14, 1987', 'Jan 19, 2018',
#        'Feb 22, 2002', 'Jan 15, 2009', 'Feb 25, 2004', 'Dec 12, 1962',
#        'Jun 11, 1993', 'Oct 15, 2003', 'May 28, 2010', 'Dec 21, 1966',
#        'Nov 25, 2011', 'May 9, 2014', 'Mar 12, 1999', 'Dec 25, 1980',
#        'May 20, 1994', 'Dec 25, 2000', 'Dec 18, 1956', 'Aug 9, 1991',
#        'Jan 1, 1989', 'Feb 9, 1957', 'Aug 1, 1973', 'Mar 18, 1959',
#        'Feb 16, 2018', 'Sep 19, 1973', 'Jan 1, 1921', 'May 30, 2003',
#        'Jan 14, 1964', 'Jul 8, 2016', 'Aug 6, 2010', 'Jul 21, 2017',
#        'Apr 22, 1994', 'Sep 5, 1956', 'Jan 26, 1972', 'Oct 13, 1981',
#        'Oct 22, 1942', 'Feb 17, 1984', 'Jun 1, 1986', 'Jun 1, 1991',
#        'Dec 14, 2012', 'Oct 25, 2002', 'Dec 3, 2004', 'Oct 19, 2001',
#        'Jul 26, 1991', 'Sep 29, 2006', 'Mar 24, 2006', 'Oct 27, 1998',
#        'Mar 18, 2009', 'Sep 27, 1947', 'Apr 1, 2005', 'Mar 4, 2016',
#        'Dec 29, 2017', 'Mar 22, 1996', 'Feb 27, 2015', 'Jan 12, 2018',
#        'Dec 16, 1994', 'Oct 24, 1993', 'Sep 26, 2003', 'May 8, 2015',
#        'Jul 19, 1991', 'Oct 5, 2007', 'Nov 10, 2000', 'Jan 11, 2003',
#        'Jul 29, 2005', 'May 30, 1986', 'Nov 7, 2008', 'Dec 11, 1991',
#        'Oct 28, 2016', 'May 26, 1995', 'Sep 5, 2003', 'Jun 1, 2006',
#        'Jun 13, 2014', 'Sep 25, 2004', 'Aug 27, 1993', 'Sep 15, 1972',
#        'Oct 21, 2016', 'Sep 16, 2011', 'Dec 25, 1981', 'Feb 11, 2005',
#        'Aug 9, 1944', 'Jan 14, 2005', 'May 26, 2000', 'Oct 1, 1997',
#        'Feb 3, 1995', 'Oct 19, 2018', 'Apr 20, 2012', 'May 20, 2005',
#        'Feb 10, 1950', 'Sep 10, 1996', 'Dec 20, 1985', 'Dec 8, 2006',
#        'Apr 12, 1991', 'Apr 29, 1988', 'Nov 8, 1981', 'Jun 24, 2005',
#        'Dec 10, 2007', 'Mar 7, 2003', 'Jun 29, 2018', 'Aug 4, 2006',
#        'Nov 23, 2012', 'Sep 16, 2002', 'May 27, 1967', 'Jul 26, 1985',
#        'Jun 9, 1994', 'Mar 30, 2001', 'Jul 20, 2001', 'Jan 28, 1983',
#        'Nov 8, 2002', 'Aug 1, 2014', 'Sep 14, 2018', 'Jul 11, 2001',
#        'Feb 20, 2004', 'Jan 10, 1992', 'Dec 9, 2016', 'Jan 12, 2000',
#        'Sep 2, 1971', 'Oct 13, 1995', 'May 12, 2017', 'Jan 30, 2004',
#        'Jan 18, 2002', 'Jul 18, 1959', 'Jul 3, 1962', 'May 10, 2000',
#        'Mar 14, 2008', 'Jan 1, 1998', 'Aug 14, 1952', 'Nov 26, 1943',
#        'Jan 30, 2015', 'Mar 5, 1999', 'Apr 7, 2000', 'Sep 17, 1971',
#        'Oct 9, 2009', 'Sep 15, 1995', 'Jun 1, 2007', 'Mar 11, 1981',
#        'Dec 18, 2015', 'Nov 13, 1967', 'Mar 2, 2018', 'Jun 1, 1953',
#        'Dec 8, 2017', 'Mar 8, 1995', 'Dec 1, 1958', 'Dec 23, 1997',
#        'Feb 1, 2008', 'Apr 9, 2010', 'Jun 9, 2017', 'Nov 11, 1992',
#        'Oct 10, 1968', 'Oct 12, 2001', 'May 28, 1999', 'Jul 24, 1981',
#        'Jan 1, 2000', 'Jun 21, 2000', 'Dec 18, 1960', 'Aug 7, 2002',
#        'Jun 1, 1990', 'Dec 2, 1994', 'Feb 8, 2008', 'Apr 4, 1980',
#        'Nov 15, 2002', 'Oct 23, 1963', 'Oct 6, 2000', 'Oct 14, 2011',
#        'Apr 12, 1985', 'May 15, 2008', 'Feb 4, 2018', 'Jun 1, 1989',
#        'May 15, 1934', 'Dec 21, 1995', 'Aug 24, 2001', 'Jun 1, 1982',
#        'Jan 16, 2015', 'Dec 29, 2000', 'Jul 5, 1991', 'Oct 5, 1998',
#        'Oct 23, 2009', 'Nov 25, 1998', 'Sep 23, 2016', 'Aug 16, 1940',
#        'Oct 30, 1987', 'Jun 24, 1958', 'Jun 20, 2014', 'Aug 15, 2008',
#        'May 1, 1987', 'Aug 8, 2008', 'Dec 20, 2011', 'Dec 16, 2005',
#        'Nov 10, 2004', 'Oct 8, 1981', 'Jul 14, 1979', 'Dec 15, 1989',
#        'Apr 15, 1994', 'Aug 8, 2007', 'Sep 1, 1999', 'Jun 15, 1979',
#        'Feb 21, 1997', 'Dec 20, 1996', 'Jan 7, 2011', 'Jan 27, 1995',
#        'Aug 18, 2017', 'Nov 9, 2012', 'Aug 9, 2013', 'Jun 7, 1985',
#        'Jun 6, 2003', 'Mar 12, 1993', 'Oct 6, 2006', 'Apr 24, 2009',
#        'Nov 16, 1959', 'Jul 26, 2000', 'Jun 24, 1965', 'Aug 23, 2013',
#        'Mar 7, 1980', 'Jul 26, 2013', 'Sep 16, 1998', 'Jan 1, 1978',
#        'Apr 13, 2018', 'Sep 24, 1993', 'Oct 20, 2006', 'Sep 25, 1992',
#        'Oct 17, 2008', 'Mar 4, 2011', 'Nov 27, 2013', 'Jul 28, 1989',
#        'May 21, 2007', 'Dec 17, 2004', 'Jul 25, 2003', 'Dec 4, 2015',
#        'Mar 1, 1997', 'Oct 10, 2002', 'Jun 3, 2009', 'Sep 13, 1995',
#        'Apr 29, 1994', 'Jan 1, 1959', 'Oct 3, 1997', 'Jan 1, 1986',
#        'Jun 1, 1994', 'Mar 1, 2002', 'Aug 26, 2011', 'Apr 10, 1998',
#        'Sep 1, 2000', 'Jan 1, 1985', 'Aug 12, 2016', 'Dec 20, 1965',
#        'May 16, 1994', 'Oct 15, 1999', 'Feb 23, 2018', 'Apr 27, 1955',
#        'Dec 29, 1939', 'Apr 17, 1997', 'Mar 11, 1977', 'Nov 13, 2015',
#        'Feb 9, 2018', 'Jan 12, 2007', 'Sep 17, 1999', 'Sep 16, 1965',
#        'Nov 27, 2002', 'Jul 18, 2014', 'Jul 23, 2004', 'Jan 1, 1984',
#        'Jun 25, 1993', 'Jan 1, 2002', 'Oct 10, 1980', 'Nov 28, 2014',
#        'Sep 30, 2005', 'Apr 29, 2011', 'Sep 26, 1997', 'Oct 9, 1992',
#        'Nov 11, 1994', 'Mar 17, 1982', 'Aug 29, 1986', 'Feb 21, 2003',
#        'Oct 6, 1980', 'Feb 5, 1993', 'Sep 8, 2000', 'Aug 4, 1983',
#        'Aug 8, 2014', 'Nov 15, 1996', 'Jul 24, 2015', 'Dec 31, 1994',
#        'Apr 14, 2000', 'Aug 23, 1985', 'Jan 1, 1955', 'Sep 9, 1988',
#        'Jul 27, 2007', 'Feb 4, 1976', 'Jul 16, 1993', 'May 15, 2009',
#        'Apr 7, 1993', 'Dec 14, 1988', 'Jul 12, 1967', 'Feb 24, 2017',
#        'Nov 3, 2000', 'Jan 21, 2011', 'Oct 25, 1991', 'May 12, 1989',
#        'Mar 16, 1984', 'Jan 1, 1969', 'Apr 2, 1999', 'Mar 29, 2018',
#        'Jul 8, 2011', 'Jun 10, 1983', 'Feb 5, 1991', 'Oct 29, 2008',
#        'Mar 17, 2017', 'Dec 6, 2002', 'Jun 12, 1998', 'Aug 3, 2007',
#        'May 26, 2017', 'Jun 14, 1996', 'Aug 15, 1997', 'Oct 11, 2004',
#        'Aug 17, 2018', 'Jan 1, 1950', 'Jul 10, 1998', 'Sep 8, 1996',
#        'Aug 7, 2009', 'Feb 28, 2003', 'Sep 20, 2013', 'Mar 2, 2007',
#        'Jun 21, 1955', 'Feb 20, 1963', 'May 1, 1981', 'May 8, 1987',
#        'Sep 23, 1983', 'Jan 1, 2003', 'Jun 16, 2008', 'Dec 31, 1986',
#        'Dec 17, 1999', 'Apr 14, 2006', 'Nov 20, 1964', 'Jun 30, 1995',
#        'Nov 20, 1981', 'Apr 10, 1966', 'Jun 1, 1975', 'Aug 1, 1981',
#        'Sep 4, 2015', 'Mar 30, 1988', 'Aug 7, 2008', 'Jun 17, 1971',
#        'Dec 10, 1993', 'Jul 14, 2006', 'Nov 23, 1988', 'Mar 20, 1992',
#        'Sep 6, 1984', 'Sep 29, 2017', 'Jul 16, 2004', 'Jan 1, 1961',
#        'Apr 27, 2001', 'Dec 5, 2003', 'Jan 14, 2011', 'Mar 17, 2000',
#        'Apr 20, 2001', 'Apr 3, 1992', 'May 3, 1985', 'Jun 2, 1995',
#        'Jun 1, 1998', 'Sep 12, 2003', 'Apr 23, 2004', 'Apr 19, 1996',
#        'Dec 23, 2011', 'Apr 1, 1976', 'Jul 6, 1988', 'Jan 30, 1998',
#        'Jul 3, 2013', 'Feb 17, 2016', 'Nov 23, 1966', 'Oct 5, 2012',
#        'Aug 30, 2002', 'Aug 21, 1991', 'Jun 4, 1993', 'Jun 30, 1999',
#        'Aug 18, 2006', 'Apr 1, 1993', 'Sep 27, 2001'], dtype=object)

# %%
#genres_w_date['Year'] = genres_w_date[genres_w_date['theater_date']].apply(get_year)
#genres_w_date.columns

# %%
#drop more superfluous columns
filled_genres.drop(labels=['review','synopsis','director','writer', 'date'],axis=1, inplace=True)
filled_genres.head()
# Out:
#    id rating_x   fresh  cleaned_rating                              genre  \
# 0   3      3/5   fresh             3.0  Drama|Science Fiction and Fantasy
# 1   3      2/5  rotten             2.0  Drama|Science Fiction and Fantasy
# 2   3      2/4  rotten             2.0  Drama|Science Fiction and Fantasy
# 3   3      3/4   fresh             3.0  Drama|Science Fiction and Fantasy
# 4   3      3/5   fresh             3.0  Drama|Science Fiction and Fantasy
#
#    theater_date currency box_office      runtime  Special Interest  ...  \
# 0  Aug 17, 2012        $    600,000  108 minutes             False  ...
# 1  Aug 17, 2012        $    600,000  108 minutes             False  ...
# 2  Aug 17, 2012        $    600,000  108 minutes             False  ...
# 3  Aug 17, 2012        $    600,000  108 minutes             False  ...
# 4  Aug 17, 2012        $    600,000  108 minutes             False  ...
#
#    Comedy  Art House and International  Kids and Family  Horror  Television  \
# 0   False                        False            False   False       False
# 1   False                        False            False   False       False
# 2   False                        False            False   False       False
# 3   False                        False            False   False       False
# 4   False                        False            False   False       False
#
#    Science Fiction and Fantasy  Romance  Anime and Manga  \
# 0                         True    False            False
# 1                         True    False            False
# 2                         True    False            False
# 3                         True    False            False
# 4                         True    False            False
#
#    Faith and Spirituality  Classics
# 0                   False     False
# 1                   False     False
# 2                   False     False
# 3                   False     False
# 4                   False     False
#
# [5 rows x 30 columns]

# %%
filled_genres.columns
# Out:
# Index(['id', 'rating_x', 'fresh', 'cleaned_rating', 'genre', 'theater_date',
#        'currency', 'box_office', 'runtime', 'Special Interest',
#        'Gay and Lesbian', 'Sports and Fitness', 'Action and Adventure',
#        'Documentary', 'Cult Movies', 'Drama', 'Animation',
#        'Mystery and Suspense', 'Western', 'Musical and Performing Arts',
#        'Comedy', 'Art House and International', 'Kids and Family', 'Horror',
#        'Television', 'Science Fiction and Fantasy', 'Romance',
#        'Anime and Manga', 'Faith and Spirituality', 'Classics'],
#       dtype='object')

# %%
#df with just cleaned_rating and individual genres for visuals
filled_genres.drop(labels=['id', 'rating_x', 'fresh', 'genre', 'theater_date', 'currency', 'box_office', 'runtime'], axis=1, inplace=True)
filled_genres.rename(columns = {'cleaned_rating': 'Rating'}, inplace=True)

# %%
filled_genres.head()
# Out:
#    Rating  Special Interest  Gay and Lesbian  Sports and Fitness  \
# 0     3.0             False            False               False
# 1     2.0             False            False               False
# 2     2.0             False            False               False
# 3     3.0             False            False               False
# 4     3.0             False            False               False
#
#    Action and Adventure  Documentary  Cult Movies  Drama  Animation  \
# 0                 False        False        False   True      False
# 1                 False        False        False   True      False
# 2                 False        False        False   True      False
# 3                 False        False        False   True      False
# 4                 False        False        False   True      False
#
#    Mystery and Suspense  ...  Comedy  Art House and International  \
# 0                 False  ...   False                        False
# 1                 False  ...   False                        False
# 2                 False  ...   False                        False
# 3                 False  ...   False                        False
# 4                 False  ...   False                        False
#
#    Kids and Family  Horror  Television  Science Fiction and Fantasy  Romance  \
# 0            False   False       False                         True    False
# 1            False   False       False                         True    False
# 2            False   False       False                         True    False
# 3            False   False       False                         True    False
# 4            False   False       False                         True    False
#
#    Anime and Manga  Faith and Spirituality  Classics
# 0            False                   False     False
# 1            False                   False     False
# 2            False                   False     False
# 3            False                   False     False
# 4            False                   False     False
#
# [5 rows x 22 columns]

# %%
#dropped rows with television rating and then the television column as only want movies and round ratings 
no_tv = filled_genres.drop(filled_genres[filled_genres['Television'] == True].index)
no_tv.drop(labels='Television', axis=1, inplace=True)
no_tv.Rating = no_tv.Rating.apply(rate_round)

# %%
no_tv.Rating.unique()
# Out:
# array([3, 2, 4, 1, 5, 0])

# %%
#df with highest ratings (4-5)
high_rate = no_tv.drop(no_tv[no_tv['Rating'] < 4.0].index)
high_rate.Rating.unique()
# Out:
# array([4, 5])

# %%
#df with mid (3) ratings 
mid_rate = no_tv.drop(no_tv[no_tv['Rating'] < 3.0].index)
mid_rate.drop(mid_rate[mid_rate['Rating'] >= 4.0].index, inplace=True)
mid_rate.Rating.unique()
# Out:
# array([3])

# %%
#df with low ratings (0-2)
low_rate = no_tv.drop(no_tv[no_tv['Rating'] >= 3].index)
low_rate.Rating.unique()
# Out:
# array([2, 1, 0])

# %%
#plot highest ratings (4 & 5) of all genres
high_sum = high_rate.groupby(['Rating']).sum()
high_sum
print('Number of high ratings:', len(high_rate))
high_sum.plot.bar(figsize=(14,8));
# Out:
# Number of high ratings: 13964

# %%
#create df of 4 ratings and plot
high4 = high_rate[high_rate['Rating']==4.00]
high4_sum = high4.groupby(['Rating']).sum()
print('Number of 4 ratings:',len(high4))
(high4_sum.T).plot.bar(figsize=(10,8));
# Out:
# Number of 4 ratings: 12261

# %%
#create df of 5 ratings of all genres and plot
high5 = high_rate[high_rate['Rating']==5.00]
high5_sum = high5.groupby(['Rating']).sum()
print('Number of 5 ratings:', len(high5))
(high5_sum.T).plot.bar(figsize=(10,8));
# Out:
# Number of 5 ratings: 1703

# %%
#create df of sum of mid rating (3) for all genres and plot
mid_sum = mid_rate.groupby(['Rating']).sum()
print('Number of average ratings:', len(mid_rate))
mid_sum.plot.bar(figsize=(14,8));
# Out:
# Number of average ratings: 11103

# %%
#create df of mid rating and plot
rate3 = mid_rate[mid_rate['Rating']==3.00]
rate3_sum = rate3.groupby(['Rating']).sum()
print('Number of ratings of 3:', len(rate3))
(rate3_sum.T).plot.bar(figsize=(10,8));
# Out:
# Number of ratings of 3: 11103

# %%
print('Number of low ratings:', len(low_rate))
low_rate_sum = low_rate.groupby(["Rating"]).sum()
low_rate_sum.plot.bar(figsize=(14,8));
# Out:
# Number of low ratings: 15567

# %%
#create df of 10 genres with highest frequency of top rating
all_high = high_rate.copy()
all_high.Rating = all_high.Rating.apply(lambda x: 5)
all_high_sum = all_high.groupby(['Rating']).sum()
top10_high = all_high_sum.T.sort_values(by=5, ascending=False)[:10]

# %%
#plot top ten genres with highest frequency of top rating
fig, ax1 = plt.subplots(figsize=(10,5));

ax1.bar(x=top10_high.index, height=top10_high[5], color='grey', edgecolor='yellow');
plt.xticks(rotation=45, ha='right');
ax1.set_title('Genres with Highest Frequency of Top Rating');

# %%
#create df of 10 genres of with highest frequency of average rating
all_mid_sum = mid_rate.groupby(['Rating']).sum()
top10_mid = all_mid_sum.T.sort_values(by=3, ascending=False)[:10]

# %%
#plot top ten genres with highest frequency of average rating
fig, ax2 = plt.subplots(figsize=(10,5));

ax2.bar(x=top10_mid.index, height=top10_mid[3], color='orange', edgecolor='blue');
plt.xticks(rotation=45, ha='right');
ax2.set_title('Genres with Highest Frequency of Average Rating');

# %%
#create df of top 10 genres with highest frequency of low rating
all_low = low_rate.copy()
all_low.Rating = all_low.Rating.apply(lambda x : 1)
all_low_sum = all_low.groupby(['Rating']).sum()
top10_low = all_low_sum.T.sort_values(by=1, ascending=False)[:10]

# %%
#plot top ten genres with highest frequency of low rating
fig, ax = plt.subplots(figsize=(10,5));

ax.bar(x=top10_low.index, height=top10_low[1], color='blue', edgecolor='red');
plt.xticks(rotation=45, ha='right');
ax.set_title('Genres with Highest Frequency of Low Rating');

# %%
#create dfs for low ratings (1,2, &3)
low0 = low_rate[low_rate['Rating']== 0]
low1 = low_rate[low_rate['Rating'] == 1]
low2 = low_rate[low_rate['Rating'] == 2]

# %%
#create sum df of 0 ratings and plot
low0_sum = low0.groupby(['Rating']).sum()
print('Number of 0 ratings:', len(low0))
(low0_sum.T).plot.bar(figsize=(10,8));
# Out:
# Number of 0 ratings: 454

# %%
#create sum df of 1 ratings and plot
low1_sum = low1.groupby(['Rating']).sum()
print('Number of 1 ratings:', len(low1))
(low1_sum.T).plot.bar(figsize=(10,8));
# Out:
# Number of 1 ratings: 2166

# %%
#create sum df of 2 ratings and plot
low2_sum = low2.groupby(['Rating']).sum()
print('Number of 2 ratings:', len(low2))
(low2_sum.T).plot.bar(figsize=(10,8));
# Out:
# Number of 2 ratings: 12947
